# %%
import os

for root, dirs, files in os.walk('/kaggle/input'):
    for f in files:
        print(os.path.join(root, f))
# Out:
# /kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4
# /kaggle/input/datasets/zlemdemir/models/operator_shadowing_best.pt

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Modeli yükleme
model = YOLO('/kaggle/input/datasets/zlemdemir/models/operator_shadowing_best.pt')

# Tracking yapma
results = model.track(
    source='/kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4',
    tracker='bytetrack.yaml',
    save=True,
    conf=0.5,
    project='/kaggle/working',
    name='tracking_sonuc'
)

print("\nTracking tamamlandı!")
import os
sonuc_klasoru = '/kaggle/working/tracking_sonuc'
for f in os.listdir(sonuc_klasoru):
    print(f'{sonuc_klasoru}/{f}')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 366ms
# Prepared 1 package in 105ms
# Installed 1 package in 6ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 1.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
# ...

# %%
from ultralytics import YOLO

# Modeli yükleme
model = YOLO('/kaggle/input/datasets/zlemdemir/models/operator_shadowing_best.pt')

# Tracking yapma
results = model.track(
    source='/kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4',
    tracker='botsort.yaml',
    save=True,
    conf=0.5,
    project='/kaggle/working',
    name='tracking_botsort'
)

print("\nTracking tamamlandı!")
import os
sonuc_klasoru = '/kaggle/working/tracking_sonuc'
for f in os.listdir(sonuc_klasoru):
    print(f'{sonuc_klasoru}/{f}')
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/593) /kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4: 384x640 1 person, 2 high-viss, 98.1ms
# video 1/1 (frame 2/593) /kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4: 384x640 1 person, 2 high-viss, 88.2ms
# video 1/1 (frame 3/593) /kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4: 384x640 1 person, 2 high-viss, 86.0ms
# ...

# %%
import os

for root, dirs, files in os.walk('/kaggle/input'):
    for f in files:
        if f.endswith('.mp4') or f.endswith('.avi') or f.endswith('.mov'):
            print(os.path.join(root, f))
# Out:
# /kaggle/input/datasets/zlemdemir/video-for-tracking/test_video_yavas.mp4
# /kaggle/input/datasets/zlemdemir/tracking-deneme-2/video_for_tracking_2.mp4

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/input/datasets/zlemdemir/models/operator_shadowing_best.pt')

results = model.track(
    source='/kaggle/input/datasets/zlemdemir/video-for-tracking-3/video_for_tracking_3.mp4',
    tracker='bytetrack.yaml',
    save=True,
    conf=0.5,
    project='/kaggle/working',
    name='tracking_video3'
)

print("\nTracking tamamlandı!")
import os
sonuc_klasoru = '/kaggle/working/tracking_video3'
for f in os.listdir(sonuc_klasoru):
    print(f'{sonuc_klasoru}/{f}')
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/331) /kaggle/input/datasets/zlemdemir/video-for-tracking-3/video_for_tracking_3.mp4: 384x640 4 persons, 142.0ms
# video 1/1 (frame 2/331) /kaggle/input/datasets/zlemdemir/video-for-tracking-3/video_for_tracking_3.mp4: 384x640 4 persons, 91.0ms
# video 1/1 (frame 3/331) /kaggle/input/datasets/zlemdemir/video-for-tracking-3/video_for_tracking_3.mp4: 384x640 4 persons, 90.4ms
# ...
